# %%
#Data processing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns                         #for visualization

#deep learning
import torch
import torch.nn as nn                         #neural network
from torchvision import models, transforms    #computer vision tool for pytorch  model-resnet transforms-text
from PIL import Image                         #python image lib(resize,open etc)

#image processing
import os                                     #os interface(check if file exists)
from pathlib import pathlib                   #file path
import joblib                                 
import time

#machine learning
from sklearn.neighbors import NearestNeighbor
from sklearn.metrics.pairwise import cosine_similarity

#settings
import warnings
warnings.filterwarnings('ignore')             #supress warnings
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

#set random seed
np.random.seed(42)
torch.manual_speed(42)
